# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np


# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %% [markdown]
# ### Intro
# - Explora y carga ambos conjuntos de datos en pandas DataFrames.
# - Identifica las columnas comunes entre los dos conjuntos de datos.
# - Utiliza el método de unión de Pandas que consideres más adecuado para combinar los datos de ambos años en un solo DataFrame.
# - Explica por qué elegiste ese método de unión y cómo se llevaron a cabo los pasos anteriores.
# - Porque son los mismos paises con información complementaria

# %%
df1= pd.read_csv("world-data-2023_part1.csv",index_col=0)
df1.head(2)
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
#
#   Capital/Major City Co2-Emissions     CPI CPI Change (%) Currency-Code  \
# 0              Kabul         8,672   149.9          2.30%           AFN
# 1             Tirana         4,536  119.05          1.40%           ALL
#
#    Fertility Rate Forested Area (%) Gasoline Price
# 0            4.47             2.10%         $0.70
# 1            1.62            28.10%         $1.36

# %%
df2=pd.read_csv("world-data-2023_part2.csv",index_col=0)
df2.head(2)
# Out:
#                 GDP Gross primary education enrollment (%)  \
# 0  $19,101,353,833                                 104.00%
# 1  $15,278,077,447                                 107.00%
#
#   Gross tertiary education enrollment (%)  Infant mortality Largest city  \
# 0                                   9.70%              47.9        Kabul
# 1                                  55.00%               7.8       Tirana
#
#    Life expectancy  Maternal mortality ratio Minimum wage Official language  \
# 0             64.5                     638.0       $0.43             Pashto
# 1             78.5                      15.0       $1.12           Albanian
#
#   Out of pocket health expenditure  Physicians per thousand  Population  \
# 0                           78.40%                     0.28  38,041,754
# 1                           56.90%                     1.20   2,854,191
#
#   Population: Labor force participation (%) Tax revenue (%) Total tax rate  \
# 0                                    48.90%           9.30%         71.40%
# 1                                    55.70%          18.60%         36.60%
#
#   Unemployment rate Urban_population      country                  coordinates
# 0            11.12%        9,797,273  Afghanistan   ('33.93911 ', '67.709953')
# 1            12.33%        1,747,593      Albania  ('41.153332 ', '20.168331')

# %%
print ("Dimensión Parte1", df1.shape)
print ("Dimensión Parte2", df2.shape)
# Out:
# Dimensión Parte1 (195, 16)
# Dimensión Parte2 (195, 19)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195 entries, 0 to 194
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                195 non-null    object
#  1   Density
# (P/Km2)        195 non-null    object
#  2   Abbreviation           188 non-null    object
#  3   Agricultural Land( %)  188 non-null    object
#  4   Land Area(Km2)         194 non-null    object
#  5   Armed Forces size      171 non-null    object
#  6   Birth Rate             189 non-null    float64
#  7   Calling Code           194 non-null    float64
#  8   Capital/Major City     192 non-null    object
#  9   Co2-Emissions          188 non-null    object
#  10  CPI                    178 non-null    object
#  11  CPI Change (%)         179 non-null    object
#  12  Currency-Code          180 non-null    object
#  13  Fertility Rate         188 non-null    float64
#  14  Forested Area (%)      188 non-null    object
#  15  Gasoline Price         175 non-null    object
# dtypes: float64(3), object(13)
# memory usage: 25.9+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195 entries, 0 to 194
# Data columns (total 19 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   GDP                                        193 non-null    object
#  1   Gross primary education enrollment (%)     188 non-null    object
#  2   Gross tertiary education enrollment (%)    183 non-null    object
#  3   Infant mortality                           189 non-null    float64
#  4   Largest city                               189 non-null    object
#  5   Life expectancy                            187 non-null    float64
#  6   Maternal mortality ratio                   181 non-null    float64
#  7   Minimum wage                               150 non-null    object
#  8   Official language                          190 non-null    object
#  9   Out of pocket health expenditure           188 non-null    object
#  10  Physicians per thousand                    188 non-null    float64
#  11  Population                                 194 non-null    object
#  12  Population: Labor force participation (%)  176 non-null    object
#  13  Tax revenue (%)                            169 non-null    object
#  14  Total tax rate                             183 non-null    object
#  15  Unemployment rate                          176 non-null    object
#  16  Urban_population                           190 non-null    object
#  17  country                                    195 non-null    object
#  18  coordinates                                195 non-null    object
# dtypes: float64(4), object(15)
# memory usage: 30.5+ KB

# %%
#Vamos a utilizar el método "merge" para unir ambos ficheros porque ambos archivos son complementarios en cuanto a diferentes métricas relacionadas con países
df_merge = df1.merge(df2,left_on= "Country", right_on= "country")

# %%
df_merge.head(5).T
# Out:
#                                                                     0  \
# Country                                                   Afghanistan
# Density\n(P/Km2)                                                   60
# Abbreviation                                                       AF
# Agricultural Land( %)                                          58.10%
# Land Area(Km2)                                                652,230
# Armed Forces size                                             323,000
# Birth Rate                                                      32.49
# Calling Code                                                     93.0
# Capital/Major City                                              Kabul
# Co2-Emissions                                                   8,672
# CPI                                                             149.9
# CPI Change (%)                                                  2.30%
# Currency-Code                                                     AFN
# Fertility Rate                                                   4.47
# Forested Area (%)                                               2.10%
# Gasoline Price                                                 $0.70
# GDP                                                  $19,101,353,833
# Gross primary education enrollment (%)                        104.00%
# Gross tertiary education enrollment (%)                         9.70%
# Infant mortality                                                 47.9
# Largest city                                                    Kabul
# Life expectancy                                                  64.5
# Maternal mortality ratio                                        638.0
# Minimum wage                                                   $0.43
# Official language                                              Pashto
# Out of pocket health expenditure                               78.40%
# Physicians per thousand                                          0.28
# Population                                                 38,041,754
# Population: Labor force participation (%)                      48.90%
# Tax revenue (%)                                                 9.30%
# Total tax rate                                                 71.40%
# Unemployment rate                                              11.12%
# Urban_population                                            9,797,273
# country                                                   Afghanistan
# coordinates                                ('33.93911 ', '67.709953')
#
#                                                                      1  \
# Country                                                        Albania
# Density\n(P/Km2)                                                   105
# Abbreviation                                                        AL
# Agricultural Land( %)                                           43.10%
# Land Area(Km2)                                                  28,748
# Armed Forces size                                                9,000
# Birth Rate                                                       11.78
# Calling Code                                                     355.0
# Capital/Major City                                              Tirana
# Co2-Emissions                                                    4,536
# CPI                                                             119.05
# CPI Change (%)                                                   1.40%
# Currency-Code                                                      ALL
# Fertility Rate                                                    1.62
# Forested Area (%)                                               28.10%
# Gasoline Price                                                  $1.36
# GDP                                                   $15,278,077,447
# Gross primary education enrollment (%)                         107.00%
# Gross tertiary education enrollment (%)                         55.00%
# Infant mortality                                                   7.8
# Largest city                                                    Tirana
# Life expectancy                                                   78.5
# Maternal mortality ratio                                          15.0
# Minimum wage                                                    $1.12
# Official language                                             Albanian
# Out of pocket health expenditure                                56.90%
# Physicians per thousand                                            1.2
# Population                                                   2,854,191
# Population: Labor force participation (%)                       55.70%
# Tax revenue (%)                                                 18.60%
# Total tax rate                                                  36.60%
# Unemployment rate                                               12.33%
# Urban_population                                             1,747,593
# country                                                        Albania
# coordinates                                ('41.153332 ', '20.168331')
#
#                                                                     2  \
# Country                                                       Algeria
# Density\n(P/Km2)                                                   18
# Abbreviation                                                       DZ
# Agricultural Land( %)                                          17.40%
# Land Area(Km2)                                              2,381,741
# Armed Forces size                                             317,000
# Birth Rate                                                      24.28
# Calling Code                                                    213.0
# Capital/Major City                                            Algiers
# Co2-Emissions                                                 150,006
# CPI                                                            151.36
# CPI Change (%)                                                  2.00%
# Currency-Code                                                     DZD
# Fertility Rate                                                   3.02
# Forested Area (%)                                               0.80%
# Gasoline Price                                                 $0.28
# GDP                                                 $169,988,236,398
# Gross primary education enrollment (%)                        109.90%
# Gross tertiary education enrollment (%)                        51.40%
# Infant mortality                                                 20.1
# Largest city                                                  Algiers
# Life expectancy                                                  76.7
# Maternal mortality ratio                                        112.0
# Minimum wage                                                   $0.95
# Official language                                              Arabic
# Out of pocket health expenditure                               28.10%
# Physicians per thousand                                          1.72
# Population                                                 43,053,054
# Population: Labor force participation (%)                      41.20%
# Tax revenue (%)                                                37.20%
# Total tax rate                                                 66.10%
# Unemployment rate                                              11.70%
# Urban_population                                           31,510,100
# country                                                       Algeria
# coordinates                                ('28.033886 ', '1.659626')
#
#                                                                     3  \
# Country                                                       Andorra
# Density\n(P/Km2)                                                  164
# Abbreviation                                                       AD
# Agricultural Land( %)                                          40.00%
# Land Area(Km2)                                                    468
# Armed Forces size                                                 NaN
# Birth Rate                                                        7.2
# Calling Code                                                    376.0
# Capital/Major City                                   Andorra la Vella
# Co2-Emissions                                                     469
# CPI                                                               NaN
# CPI Change (%)                                                    NaN
# Currency-Code                                                     EUR
# Fertility Rate                                                   1.27
# Forested Area (%)                                              34.00%
# Gasoline Price                                                 $1.51
# GDP                                                   $3,154,057,987
# Gross primary education enrollment (%)                        106.40%
# Gross tertiary education enrollment (%)                           NaN
# Infant mortality                                                  2.7
# Largest city                                         Andorra la Vella
# Life expectancy                                                   NaN
# Maternal mortality ratio                                          NaN
# Minimum wage                                                   $6.63
# Official language                                             Catalan
# Out of pocket health expenditure                               36.40%
# Physicians per thousand                                          3.33
# Population                                                     77,142
# Population: Labor force participation (%)                         NaN
# Tax revenue (%)                                                   NaN
# Total tax rate                                                    NaN
# Unemployment rate                                                 NaN
# Urban_population                                               67,873
# country                                                       Andorra
# coordinates                                ('42.506285 ', '1.521801')
#
#                                                                       4
# Country                                                          Angola
# Density\n(P/Km2)                                                     26
# Abbreviation                                                         AO
# Agricultural Land( %)                                            47.50%
# Land Area(Km2)                                                1,246,700
# Armed Forces size                                               117,000
# Birth Rate                                                        40.73
# Calling Code                                                      244.0
# Capital/Major City                                               Luanda
# Co2-Emissions                                                    34,693
# CPI                                                              261.73
# CPI Change (%)                                                   17.10%
# Currency-Code                                                       AOA
# Fertility Rate                                                     5.52
# Forested Area (%)                                                46.30%
# Gasoline Price                                                   $0.97
# GDP                                                    $94,635,415,870
# Gross primary education enrollment (%)                          113.50%
# Gross tertiary education enrollment (%)                           9.30%
# Infant mortality                                                   51.6
# Largest city                                                     Luanda
# Life expectancy                                                    60.8
# Maternal mortality ratio                                          241.0
# Minimum wage                                                     $0.71
# Official language                                            Portuguese
# Out of pocket health expenditure                                 33.40%
# Physicians per thousand                                            0.21
# Population                                                   31,825,295
# Population: Labor force participation (%)                        77.50%
# Tax revenue (%)                                                   9.20%
# Total tax rate                                                   49.10%
# Unemployment rate                                                 6.89%
# Urban_population                                             21,061,025
# country                                                          Angola
# coordinates                                ('-11.202692 ', '17.873887')

# %% [markdown]
# ### Ejercicios de Limpieza
# 1.  Después de la unión de datos, tenemos dos columnas de "country". Elimina una de ellas.
# 2. Los nombres de las columnas no son homogeneos. Cambia los nombres de las columnas de tal forma que:
#     2.1. No tengan espacios.
#     2.2. Estén en minúscula.
#     2.3. No tengan paréntesis, es decir, quitar "(%)", "(Km2)".
#     2.4. Algunas columnas tiene "\n". Eliminalos de los nombres de las columnas.
#     2.5. Algunas columnas tienen ":". Eliminalos de los nombres de las columnas.
# 3. La columnas coordinates tiene la latitud y la longitud en una sola columna. Crea dos columnas nuevas, una con la longitud y otra con la latitud. Una vez hecho, elimina la columna de coordinates.
# 4. Las columnas unemployment_rate, total_tax_rate, tax_revenue, population_labor_force_participation, out_of_pocket_health_expenditure, gross_tertiary_education_enrollment, gross_primary_education_enrollment, forested_area, cpi_change, agricultural_land tienen "%". Elimina los "%" de los valores de las columnas.
# 5. Haz lo mismo para las columnas de gasoline_price, gdp, minimum_wage, pero eliminando "$".
# 6. Guarda el DataFrame para usarlo en el pairprogramming de mañana.

# %% [markdown]
# ##### 1. Después de la unión de datos, tenemos dos columnas de "country". Elimina una de ellas

# %%
df_merge.drop("country", axis=1, inplace= True)

# %%
df_merge.head(2).T
# Out:
#                                                                     0  \
# Country                                                   Afghanistan
# Density\n(P/Km2)                                                   60
# Abbreviation                                                       AF
# Agricultural Land( %)                                          58.10%
# Land Area(Km2)                                                652,230
# Armed Forces size                                             323,000
# Birth Rate                                                      32.49
# Calling Code                                                     93.0
# Capital/Major City                                              Kabul
# Co2-Emissions                                                   8,672
# CPI                                                             149.9
# CPI Change (%)                                                  2.30%
# Currency-Code                                                     AFN
# Fertility Rate                                                   4.47
# Forested Area (%)                                               2.10%
# Gasoline Price                                                 $0.70
# GDP                                                  $19,101,353,833
# Gross primary education enrollment (%)                        104.00%
# Gross tertiary education enrollment (%)                         9.70%
# Infant mortality                                                 47.9
# Largest city                                                    Kabul
# Life expectancy                                                  64.5
# Maternal mortality ratio                                        638.0
# Minimum wage                                                   $0.43
# Official language                                              Pashto
# Out of pocket health expenditure                               78.40%
# Physicians per thousand                                          0.28
# Population                                                 38,041,754
# Population: Labor force participation (%)                      48.90%
# Tax revenue (%)                                                 9.30%
# Total tax rate                                                 71.40%
# Unemployment rate                                              11.12%
# Urban_population                                            9,797,273
# coordinates                                ('33.93911 ', '67.709953')
#
#                                                                      1
# Country                                                        Albania
# Density\n(P/Km2)                                                   105
# Abbreviation                                                        AL
# Agricultural Land( %)                                           43.10%
# Land Area(Km2)                                                  28,748
# Armed Forces size                                                9,000
# Birth Rate                                                       11.78
# Calling Code                                                     355.0
# Capital/Major City                                              Tirana
# Co2-Emissions                                                    4,536
# CPI                                                             119.05
# CPI Change (%)                                                   1.40%
# Currency-Code                                                      ALL
# Fertility Rate                                                    1.62
# Forested Area (%)                                               28.10%
# Gasoline Price                                                  $1.36
# GDP                                                   $15,278,077,447
# Gross primary education enrollment (%)                         107.00%
# Gross tertiary education enrollment (%)                         55.00%
# Infant mortality                                                   7.8
# Largest city                                                    Tirana
# Life expectancy                                                   78.5
# Maternal mortality ratio                                          15.0
# Minimum wage                                                    $1.12
# Official language                                             Albanian
# Out of pocket health expenditure                                56.90%
# Physicians per thousand                                            1.2
# Population                                                   2,854,191
# Population: Labor force participation (%)                       55.70%
# Tax revenue (%)                                                 18.60%
# Total tax rate                                                  36.60%
# Unemployment rate                                               12.33%
# Urban_population                                             1,747,593
# coordinates                                ('41.153332 ', '20.168331')

# %% [markdown]
# ##### 2. Homogeneizar las columnas

# %%
nuevas_columnas={columna:columna.replace(" ", "").lower().replace("\n","").replace(":", "").replace("(%)","").replace("(km)","").replace("(km2)","").replace("(Km2)","").replace("(p/km2)","") for columna in df_merge}

# %%
nuevas_columnas
# Out:
# {'Country': 'country',
#  'Density\n(P/Km2)': 'density',
#  'Abbreviation': 'abbreviation',
#  'Agricultural Land( %)': 'agriculturalland',
#  'Land Area(Km2)': 'landarea',
#  'Armed Forces size': 'armedforcessize',
#  'Birth Rate': 'birthrate',
#  'Calling Code': 'callingcode',
#  'Capital/Major City': 'capital/majorcity',
#  'Co2-Emissions': 'co2-emissions',
#  'CPI': 'cpi',
#  'CPI Change (%)': 'cpichange',
#  'Currency-Code': 'currency-code',
#  'Fertility Rate': 'fertilityrate',
#  'Forested Area (%)': 'forestedarea',
#  'Gasoline Price': 'gasolineprice',
#  'GDP': 'gdp',
#  'Gross primary education enrollment (%)': 'grossprimaryeducationenrollment',
#  'Gross tertiary education enrollment (%)': 'grosstertiaryeducationenrollment',
#  'Infant mortality': 'infantmortality',
#  'Largest city': 'largestcity',
#  'Life expectancy': 'lifeexpectancy',
#  'Maternal mortality ratio': 'maternalmortalityratio',
#  'Minimum wage': 'minimumwage',
#  'Official language': 'officiallanguage',
#  'Out of pocket health expenditure': 'outofpockethealthexpenditure',
#  'Physicians per thousand': 'physiciansperthousand',
#  'Population': 'population',
#  'Population: Labor force participation (%)': 'populationlaborforceparticipation',
#  'Tax revenue (%)': 'taxrevenue',
#  'Total tax rate': 'totaltaxrate',
#  'Unemployment rate': 'unemploymentrate',
#  'Urban_population': 'urban_population',
#  'coordinates': 'coordinates'}

# %%
df_merge.rename(columns= nuevas_columnas, inplace= True) #Aquí estamos cambiando las columnas antiguas por las homogenizadas que hemos cambiado en el paso anterior

# %%
df_merge.head(2).T
# Out:
#                                                             0  \
# country                                           Afghanistan
# density                                                    60
# abbreviation                                               AF
# agriculturalland                                       58.10%
# landarea                                              652,230
# armedforcessize                                       323,000
# birthrate                                               32.49
# callingcode                                              93.0
# capital/majorcity                                       Kabul
# co2-emissions                                           8,672
# cpi                                                     149.9
# cpichange                                               2.30%
# currency-code                                             AFN
# fertilityrate                                            4.47
# forestedarea                                            2.10%
# gasolineprice                                          $0.70
# gdp                                          $19,101,353,833
# grossprimaryeducationenrollment                       104.00%
# grosstertiaryeducationenrollment                        9.70%
# infantmortality                                          47.9
# largestcity                                             Kabul
# lifeexpectancy                                           64.5
# maternalmortalityratio                                  638.0
# minimumwage                                            $0.43
# officiallanguage                                       Pashto
# outofpockethealthexpenditure                           78.40%
# physiciansperthousand                                    0.28
# population                                         38,041,754
# populationlaborforceparticipation                      48.90%
# taxrevenue                                              9.30%
# totaltaxrate                                           71.40%
# unemploymentrate                                       11.12%
# urban_population                                    9,797,273
# coordinates                        ('33.93911 ', '67.709953')
#
#                                                              1
# country                                                Albania
# density                                                    105
# abbreviation                                                AL
# agriculturalland                                        43.10%
# landarea                                                28,748
# armedforcessize                                          9,000
# birthrate                                                11.78
# callingcode                                              355.0
# capital/majorcity                                       Tirana
# co2-emissions                                            4,536
# cpi                                                     119.05
# cpichange                                                1.40%
# currency-code                                              ALL
# fertilityrate                                             1.62
# forestedarea                                            28.10%
# gasolineprice                                           $1.36
# gdp                                           $15,278,077,447
# grossprimaryeducationenrollment                        107.00%
# grosstertiaryeducationenrollment                        55.00%
# infantmortality                                            7.8
# largestcity                                             Tirana
# lifeexpectancy                                            78.5
# maternalmortalityratio                                    15.0
# minimumwage                                             $1.12
# officiallanguage                                      Albanian
# outofpockethealthexpenditure                            56.90%
# physiciansperthousand                                      1.2
# population                                           2,854,191
# populationlaborforceparticipation                       55.70%
# taxrevenue                                              18.60%
# totaltaxrate                                            36.60%
# unemploymentrate                                        12.33%
# urban_population                                     1,747,593
# coordinates                        ('41.153332 ', '20.168331')

# %% [markdown]
# ##### 3. Las columnas coordinates tiene la latitud y la longitud en una sola columna. Crea dos columnas nuevas, una con la longitud y otra con la latitud. Una vez hecho, elimina la columna de coordinates

# %%
# Primero: Dividimos la columna en 2 (separadas por la coma)
df_merge["coordinates"].str.split(",", expand= True)
# Out:
#                   0               1
# 0      ('33.93911 '    '67.709953')
# 1     ('41.153332 '    '20.168331')
# 2     ('28.033886 '     '1.659626')
# 3     ('42.506285 '     '1.521801')
# 4    ('-11.202692 '    '17.873887')
# ..              ...             ...
# 190     ('6.42375 '    '-66.58973')
# 191   ('14.058324 '   '108.277199')
# 192   ('15.552727 '    '48.516388')
# 193  ('-13.133897 '    '27.849332')
# 194  ('-19.015438 '    '29.154857')
#
# [195 rows x 2 columns]

# %%
#Segundo: Creamos las 2 columnas en nuestro DataFrame
df_merge[["longitud","latitud"]]= df_merge["coordinates"].str.split(",", expand= True)

# %%
df_merge.head(2).T
# Out:
#                                                             0  \
# country                                           Afghanistan
# density                                                    60
# abbreviation                                               AF
# agriculturalland                                       58.10%
# landarea                                              652,230
# armedforcessize                                       323,000
# birthrate                                               32.49
# callingcode                                              93.0
# capital/majorcity                                       Kabul
# co2-emissions                                           8,672
# cpi                                                     149.9
# cpichange                                               2.30%
# currency-code                                             AFN
# fertilityrate                                            4.47
# forestedarea                                            2.10%
# gasolineprice                                          $0.70
# gdp                                          $19,101,353,833
# grossprimaryeducationenrollment                       104.00%
# grosstertiaryeducationenrollment                        9.70%
# infantmortality                                          47.9
# largestcity                                             Kabul
# lifeexpectancy                                           64.5
# maternalmortalityratio                                  638.0
# minimumwage                                            $0.43
# officiallanguage                                       Pashto
# outofpockethealthexpenditure                           78.40%
# physiciansperthousand                                    0.28
# population                                         38,041,754
# populationlaborforceparticipation                      48.90%
# taxrevenue                                              9.30%
# totaltaxrate                                           71.40%
# unemploymentrate                                       11.12%
# urban_population                                    9,797,273
# coordinates                        ('33.93911 ', '67.709953')
# longitud                                         ('33.93911 '
# latitud                                          '67.709953')
#
#                                                              1
# country                                                Albania
# density                                                    105
# abbreviation                                                AL
# agriculturalland                                        43.10%
# landarea                                                28,748
# armedforcessize                                          9,000
# birthrate                                                11.78
# callingcode                                              355.0
# capital/majorcity                                       Tirana
# co2-emissions                                            4,536
# cpi                                                     119.05
# cpichange                                                1.40%
# currency-code                                              ALL
# fertilityrate                                             1.62
# forestedarea                                            28.10%
# gasolineprice                                           $1.36
# gdp                                           $15,278,077,447
# grossprimaryeducationenrollment                        107.00%
# grosstertiaryeducationenrollment                        55.00%
# infantmortality                                            7.8
# largestcity                                             Tirana
# lifeexpectancy                                            78.5
# maternalmortalityratio                                    15.0
# minimumwage                                             $1.12
# officiallanguage                                      Albanian
# outofpockethealthexpenditure                            56.90%
# physiciansperthousand                                      1.2
# population                                           2,854,191
# populationlaborforceparticipation                       55.70%
# taxrevenue                                              18.60%
# totaltaxrate                                            36.60%
# unemploymentrate                                        12.33%
# urban_population                                     1,747,593
# coordinates                        ('41.153332 ', '20.168331')
# longitud                                         ('41.153332 '
# latitud                                           '20.168331')

# %%
#Tercero: Eliminamos la columna de coordinates
df_merge.drop("coordinates", axis=1, inplace= True)

# %%
df_merge.head(2).T
# Out:
#                                                   0                 1
# country                                 Afghanistan           Albania
# density                                          60               105
# abbreviation                                     AF                AL
# agriculturalland                             58.10%            43.10%
# landarea                                    652,230            28,748
# armedforcessize                             323,000             9,000
# birthrate                                     32.49             11.78
# callingcode                                    93.0             355.0
# capital/majorcity                             Kabul            Tirana
# co2-emissions                                 8,672             4,536
# cpi                                           149.9            119.05
# cpichange                                     2.30%             1.40%
# currency-code                                   AFN               ALL
# fertilityrate                                  4.47              1.62
# forestedarea                                  2.10%            28.10%
# gasolineprice                                $0.70             $1.36
# gdp                                $19,101,353,833   $15,278,077,447
# grossprimaryeducationenrollment             104.00%           107.00%
# grosstertiaryeducationenrollment              9.70%            55.00%
# infantmortality                                47.9               7.8
# largestcity                                   Kabul            Tirana
# lifeexpectancy                                 64.5              78.5
# maternalmortalityratio                        638.0              15.0
# minimumwage                                  $0.43             $1.12
# officiallanguage                             Pashto          Albanian
# outofpockethealthexpenditure                 78.40%            56.90%
# physiciansperthousand                          0.28               1.2
# population                               38,041,754         2,854,191
# populationlaborforceparticipation            48.90%            55.70%
# taxrevenue                                    9.30%            18.60%
# totaltaxrate                                 71.40%            36.60%
# unemploymentrate                             11.12%            12.33%
# urban_population                          9,797,273         1,747,593
# longitud                               ('33.93911 '     ('41.153332 '
# latitud                                '67.709953')      '20.168331')

# %% [markdown]
# ##### 4. Las columnas unemployment_rate, total_tax_rate, tax_revenue, population_labor_force_participation, out_of_pocket_health_expenditure, gross_tertiary_education_enrollment, gross_primary_education_enrollment, forested_area, cpi_change, agricultural_land tienen "%". Elimina los "%" de los valores de las columnas

# %%
# Paso 1. Creo una lista con las columnas que quiero modificar para luego hacer un "for" para cambiar los datos de esas columnas solamente
porcent = ["unemploymentrate", "totaltaxrate", "taxrevenue", "populationlaborforceparticipation", "outofpockethealthexpenditure", "grosstertiaryeducationenrollment", "grossprimaryeducationenrollment", "forestedarea", "cpichange", "agriculturalland"]

# Paso 2. Hago el for loop
for col in porcent:
    df_merge[col] = df_merge[col].str.replace("%", "")

# Paso 3. Verifico que los % han desaparecido
df_merge.head(2).T
# Out:
#                                                   0                 1
# country                                 Afghanistan           Albania
# density                                          60               105
# abbreviation                                     AF                AL
# agriculturalland                              58.10             43.10
# landarea                                    652,230            28,748
# armedforcessize                             323,000             9,000
# birthrate                                     32.49             11.78
# callingcode                                    93.0             355.0
# capital/majorcity                             Kabul            Tirana
# co2-emissions                                 8,672             4,536
# cpi                                           149.9            119.05
# cpichange                                      2.30              1.40
# currency-code                                   AFN               ALL
# fertilityrate                                  4.47              1.62
# forestedarea                                   2.10             28.10
# gasolineprice                                $0.70             $1.36
# gdp                                $19,101,353,833   $15,278,077,447
# grossprimaryeducationenrollment              104.00            107.00
# grosstertiaryeducationenrollment               9.70             55.00
# infantmortality                                47.9               7.8
# largestcity                                   Kabul            Tirana
# lifeexpectancy                                 64.5              78.5
# maternalmortalityratio                        638.0              15.0
# minimumwage                                  $0.43             $1.12
# officiallanguage                             Pashto          Albanian
# outofpockethealthexpenditure                  78.40             56.90
# physiciansperthousand                          0.28               1.2
# population                               38,041,754         2,854,191
# populationlaborforceparticipation             48.90             55.70
# taxrevenue                                     9.30             18.60
# totaltaxrate                                  71.40             36.60
# unemploymentrate                              11.12             12.33
# urban_population                          9,797,273         1,747,593
# longitud                               ('33.93911 '     ('41.153332 '
# latitud                                '67.709953')      '20.168331')

# %% [markdown]
# ##### 5. Haz lo mismo para las columnas de gasoline_price, gdp, minimum_wage, pero eliminando "$"

# %%
# Paso 1. Creo una lista con las columnas que quiero modificar para luego hacer un "for" para cambiar los datos de esas columnas solamente
dolar = ["gasolineprice", "gdp", "minimumwage"]

# Paso 2. Hago el for loop
for col in dolar:
    df_merge[col] = df_merge[col].str.replace("$", "")

# Paso 3. Verifico que los $ han desaparecido
df_merge.head(2).T
# Out:
# /tmp/ipykernel_351/850541583.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_merge[col] = df_merge[col].str.replace("$", "")
#                                                  0                1
# country                                Afghanistan          Albania
# density                                         60              105
# abbreviation                                    AF               AL
# agriculturalland                             58.10            43.10
# landarea                                   652,230           28,748
# armedforcessize                            323,000            9,000
# birthrate                                    32.49            11.78
# callingcode                                   93.0            355.0
# capital/majorcity                            Kabul           Tirana
# co2-emissions                                8,672            4,536
# cpi                                          149.9           119.05
# cpichange                                     2.30             1.40
# currency-code                                  AFN              ALL
# fertilityrate                                 4.47             1.62
# forestedarea                                  2.10            28.10
# gasolineprice                                0.70             1.36
# gdp                                19,101,353,833   15,278,077,447
# grossprimaryeducationenrollment             104.00           107.00
# grosstertiaryeducationenrollment              9.70            55.00
# infantmortality                               47.9              7.8
# largestcity                                  Kabul           Tirana
# lifeexpectancy                                64.5             78.5
# maternalmortalityratio                       638.0             15.0
# minimumwage                                  0.43             1.12
# officiallanguage                            Pashto         Albanian
# outofpockethealthexpenditure                 78.40            56.90
# physiciansperthousand                         0.28              1.2
# population                              38,041,754        2,854,191
# populationlaborforceparticipation            48.90            55.70
# taxrevenue                                    9.30            18.60
# totaltaxrate                                 71.40            36.60
# unemploymentrate                             11.12            12.33
# urban_population                         9,797,273        1,747,593
# longitud                              ('33.93911 '    ('41.153332 '
# latitud                               '67.709953')     '20.168331')

# %% [markdown]
# ##### 6. Guarda el DataFrame para usarlo en el pairprogramming de mañana

# %%
df_merge.to_csv("fichero_limpio.csv")

# %% [markdown]
# ### Ejercicios de Filtrado
# - Encuentra todos los países cuya mortalidad infantil esté entre 40 y 50 personas por kilómetro cuadrado.
# - Encuentra los países cuyas tasas de natalidad son mayores o iguales a 20 y su esperanza de vida es mayor de 75 años.
# - Encuentra las ciudades cuyos paises contienen la palabra "la" en su nombre.
# - Encuentra los países cuyos medicos por cada 1000 habitantes (physicians_per_thousand) sea mayores de 5.
# - Encuentra los países cuyatasa de fertilidad sea mayor a 6.
# - Encuentra los países cuya moneda es el euro (EUR) y tienen una tasa de natalidad superior al promedio.
# - Encuentra los países cuyas tasas de mortalidad infantil son superiores a 70

# %% [markdown]
# ##### Encuentra todos los países cuya mortalidad infantil esté entre 40 y 50 personas por kilómetro cuadrado

# %%
df_merge.loc[(df_merge["infantmortality"].between(40,50)), "country"]
# Out:
# 0       Afghanistan
# 26     Burkina Faso
# 27          Burundi
# 47         Djibouti
# 72            Haiti
# 89         Kiribati
# 125           Niger
# 166           Sudan
# 175            Togo
# 192           Yemen
# 193          Zambia
# Name: country, dtype: object

# %% [markdown]
# ##### Encuentra los países cuyas tasas de natalidad son mayores o iguales a 20 y su esperanza de vida es mayor de 75 años

# %%
df_merge.loc[((df_merge["birthrate"]>=20) & (df_merge["lifeexpectancy"]>=75)), "country"]
# Out:
# 2      Algeria
# 74    Honduras
# 82      Israel
# Name: country, dtype: object

# %% [markdown]
# ##### Encuentra las ciudades cuyos paises contienen la palabra "la" en su nombre

# %%
df_merge[df_merge["capital/majorcity"].str.contains('la', case=False, regex = True, na = False)]
# Out:
#                country density abbreviation agriculturalland   landarea  \
# 3              Andorra     164           AD            40.00        468
# 53   Equatorial Guinea      50           GQ            10.10     28,051
# 68           Guatemala     167           GT            36.00    108,889
# 103           Malaysia      99           MY            26.30    329,847
# 114           Mongolia       2           MN            71.50  1,564,116
# 131           Pakistan     287           PK            47.80    796,095
# 138        Philippines     368           PH            41.70    300,000
# 157           Slovakia     114           SK            39.20     49,035
# 182             Uganda     229           UG            71.90    241,038
# 189            Vanuatu      25           VU            15.30     12,189
#
#     armedforcessize  birthrate  callingcode capital/majorcity co2-emissions  \
# 3               NaN       7.20        376.0  Andorra la Vella           469
# 53            1,000      33.24        240.0            Malabo         5,655
# 68           43,000      24.56        502.0    Guatemala City        16,777
# 103         136,000      16.75         60.0      Kuala Lumpur       248,289
# 114          18,000      24.13        976.0       Ulaanbaatar        25,368
# 131         936,000      28.25         92.0         Islamabad       201,150
# 138         153,000      20.55         63.0            Manila       122,287
# 157          16,000      10.60        421.0        Bratislava        32,424
# 182          46,000      38.14        256.0           Kampala         5,680
# 189             NaN      29.60        678.0         Port Vila           147
#
#         cpi cpichange currency-code  fertilityrate forestedarea gasolineprice  \
# 3       NaN       NaN           EUR           1.27        34.00         1.51
# 53   124.35      1.20           XAF           4.51        55.50           NaN
# 68   142.92      3.70           GTQ           2.87        32.70         0.79
# 103  121.46      0.70           MYR           2.00        67.60         0.45
# 114  195.76      7.30           MNT           2.90         8.00         0.72
# 131  182.32     10.60           PKR           3.51         1.90         0.79
# 138  129.61      2.50           PHP           2.58        27.80         0.86
# 157  115.34      2.70           EUR           1.52        40.40         1.32
# 182  173.87      2.90           UGX           4.96         9.70         0.94
# 189  117.13      2.80           VUV           3.78        36.10         1.31
#
#                   gdp grossprimaryeducationenrollment  \
# 3      3,154,057,987                           106.40
# 53    11,026,774,945                            61.80
# 68    76,710,385,880                           101.90
# 103  364,701,517,788                           105.30
# 114   13,852,850,259                           104.00
# 131  304,400,000,000                            94.30
# 138  376,795,508,680                           107.50
# 157  105,422,304,976                            98.70
# 182   34,387,229,486                           102.70
# 189      917,058,851                           109.30
#
#     grosstertiaryeducationenrollment  infantmortality       largestcity  \
# 3                                NaN              2.7  Andorra la Vella
# 53                              1.90             62.6            Malabo
# 68                             21.80             22.1    Guatemala City
# 103                            45.10              6.7       Johor Bahru
# 114                            65.60             14.0       Ulaanbaatar
# 131                             9.00             57.2           Karachi
# 138                            35.50             22.5            Manila
# 157                            46.60              4.6        Bratislava
# 182                             4.80             33.8           Buganda
# 189                             4.70             22.3         Port Vila
#
#      lifeexpectancy  maternalmortalityratio minimumwage    officiallanguage  \
# 3               NaN                     NaN       6.63              Catalan
# 53             58.4                   301.0       1.05              Spanish
# 68             74.1                    95.0       1.60              Spanish
# 103            76.0                    29.0       0.93   Malaysian language
# 114            69.7                    45.0       0.65            Mongolian
# 131            67.1                   140.0       0.69                 Urdu
# 138            71.1                   121.0       1.12              English
# 157            77.2                     5.0       3.11               Slovak
# 182            63.0                   375.0       0.01              Swahili
# 189            70.3                    72.0       1.56               French
#
#     outofpockethealthexpenditure  physiciansperthousand   population  \
# 3                          36.40                   3.33       77,142
# 53                         72.00                   0.40    1,355,986
# 68                         55.80                   0.35   16,604,026
# 103                        36.70                   1.51   32,447,385
# 114                        39.30                   2.86    3,225,167
# 131                        66.50                   0.98  216,565,318
# 138                        53.50                   0.60  108,116,615
# 157                        18.40                   3.42    5,454,073
# 182                        40.50                   0.17   44,269,594
# 189                         8.90                   0.17      299,882
#
#     populationlaborforceparticipation taxrevenue totaltaxrate  \
# 3                                 NaN        NaN          NaN
# 53                              62.00       6.10        79.40
# 68                              62.30      10.60        35.20
# 103                             64.30      12.00        38.70
# 114                             59.70      16.80        25.70
# 131                             52.60       9.20        33.90
# 138                             59.60      14.00        43.10
# 157                             59.50      18.70        49.70
# 182                             70.30      11.70        33.70
# 189                             69.90      17.80         8.50
#
#     unemploymentrate urban_population        longitud         latitud
# 3                NaN           67,873   ('42.506285 '     '1.521801')
# 53              6.43          984,812    ('1.650801 '    '10.267895')
# 68              2.46        8,540,945   ('15.783471 '   '-90.230759')
# 103             3.32       24,475,766    ('4.210484 '   '101.975766')
# 114             6.01        2,210,626   ('46.862496 '   '103.846656')
# 131             4.45       79,927,762   ('30.375321 '    '69.345116')
# 138             2.15       50,975,903   ('12.879721 '   '121.774017')
# 157             5.56        2,930,419   ('48.669026 '    '19.699024')
# 182             1.84       10,784,516    ('1.373333 '    '32.290275')
# 189             4.39           76,152  ('-15.376706 '   '166.959158')

# %% [markdown]
# ##### Encuentra los países cuyos medicos por cada 1000 habitantes (physicians_per_thousand) sea mayores de 5

# %%
df_merge.loc[(df_merge["physiciansperthousand"] > 5), "country"]
# Out:
# 9         Austria
# 15        Belarus
# 42           Cuba
# 63        Georgia
# 66         Greece
# 99      Lithuania
# 113        Monaco
# 140      Portugal
# 149    San Marino
# 187       Uruguay
# Name: country, dtype: object

# %% [markdown]
# ##### Encuentra los países cuyatasa de fertilidad sea mayor a 6

# %%
df_merge.loc[(df_merge["fertilityrate"] > 6), "country"]
# Out:
# 125      Niger
# 160    Somalia
# Name: country, dtype: object

# %% [markdown]
# ##### Encuentra los países cuya moneda es el euro (EUR) y tienen una tasa de natalidad superior al promedio

# %%
df_merge.loc[(df_merge["currency-code"] == "EUR"), "country"]
# Out:
# 3                  Andorra
# 9                  Austria
# 16                 Belgium
# 43                  Cyprus
# 55                 Estonia
# 59                 Finland
# 60                  France
# 64                 Germany
# 66                  Greece
# 73            Vatican City
# 81     Republic of Ireland
# 83                   Italy
# 93                  Latvia
# 99               Lithuania
# 100             Luxembourg
# 106                  Malta
# 113                 Monaco
# 115             Montenegro
# 140               Portugal
# 149             San Marino
# 157               Slovakia
# 158               Slovenia
# 164                  Spain
# Name: country, dtype: object

# %% [markdown]
# ##### Encuentra los países cuyas tasas de mortalidad infantil son superiores a 70

# %%
df_merge.loc[(df_merge["infantmortality"] > 70), "country"]
# Out:
# 33     Central African Republic
# 34                         Chad
# 126                     Nigeria
# 155                Sierra Leone
# 160                     Somalia
# Name: country, dtype: object
